# %%
import pandas as pd
import matplotlib.pyplot as plt
data_frame = pd.read_csv("housedata.csv")

#performing initial exproration on data_frame_housedata


data_frame.head()

data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
data_frame
data_frame["grade"].describe()
# Out:
# count    21613.000000
# mean         7.656873
# std          1.175459
# min          1.000000
# 25%          7.000000
# 50%          7.000000
# 75%          8.000000
# max         13.000000
# Name: grade, dtype: float64

# %%
print(data_frame.shape) # shows number of rows and columns in dataframe
print(data_frame.info())
print(data_frame.describe())
data_frame.hist(bins=30)
print(plt.show())
from pandas.plotting import scatter_matrix
attributes = ["yr_built","price"]
scatter_matrix(data_frame[attributes])
plt.show()
data_frame.corr()
# Out:
# (21613, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %% [markdown]
# # Relations
# We can create relations between the price,bedrooms,bathrooms,sqftliving,floors,year built,year renovated,condition,view

# %% [markdown]
# # Features
# The features i will be using are price,bedrooms,bathrooms,sqftliving,year built,year renovated and conditions.
# i would want to predict the price based on three above factors.

# %%
# data_frame.drop(labels="Subgroup", axis='columns', inplace=True)
print(data_frame.shape)
data_frame.head()
# Out:
# (21613, 21)
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
def category(x):
    if x <300000:
        return 1
    elif x >300000 and x<700000:
        return 2
    else:
        return 3
data_frame["priceCategory"] = data_frame["price"].apply(lambda x: category(x))
print(data_frame.tail())
"""def sqftcat(y):
    if y <1000:
        return 1
    elif y>1000 and y<2000:
        return 2
    elif y>2000 and y<3000:
        return 3
    elif y>3000 and y<4000:
        return 4
    elif y>4000 and y<6000:
        return 5
    elif y>6000 and y<8000:
        return 6
    elif y>8000 and y<10000:
        return 7
    elif y>10000 and y<14000:
        return 8
    else:
        return 9
data_frame["sqftcat"]= data_frame["sqft_living"].apply(lambda y: sqftcat(y))
print(data_frame.tail())"""
factors= data_frame[["bedrooms","yr_built"]]
factors.head()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 21608         1530      1131     3.0           0     0  ...        1530
# 21609         2310      5813     2.0           0     0  ...        2310
# 21610         1020      1350     2.0           0     0  ...        1020
# 21611         1600      2388     2.0           0     0  ...        1600
# 21612         1020      1076     2.0           0     0  ...        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
factors_pred = data_frame[["priceCategory"]]

# %%
factors_pred.head()
# Out:
#    priceCategory
# 0              1
# 1              2
# 2              1
# 3              2
# 4              2

# %%
factors.head()
# Out:
#    bedrooms  yr_built
# 0         3      1955
# 1         3      1951
# 2         2      1933
# 3         4      1965
# 4         3      1987

# %%
factors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 2 columns):
# bedrooms    21613 non-null int64
# yr_built    21613 non-null int64
# dtypes: int64(2)
# memory usage: 337.8 KB

# %%
import numpy as np

# %%
x = np.array(factors)

# %%
from sklearn.preprocessing import StandardScaler
standardScalerX = StandardScaler()
xScaling = standardScalerX.fit_transform(factors)
print(xScaling)

yScaling = standardScalerX.fit_transform(factors_pred)
print(yScaling)
# Out:
# [[-0.39873715 -0.54489777]
#  [-0.39873715 -0.6810785 ]
#  [-1.47395936 -1.29389179]
#  ...
#  [-1.47395936  1.29354209]
#  [-0.39873715  1.12331618]
#  [-1.47395936  1.25949691]]
# [[-1.55900968]
#  [-0.00775162]
#  [-1.55900968]
#  ...
#  [-0.00775162]
#  [-0.00775162]
#  [-0.00775162]]

# %%
print(len(xScaling))
# Out:
# 21613

# %%
y = np.array(xScaling)

# %%
print(len(yScaling))
# Out:
# 21613

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(xScaling,yScaling,test_size = 0.25,random_state=121)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
print(len(x_train),len(y_train))
# Out:
# 16209 16209

# %%
print(len(x_test),len(y_test))
# Out:
# 5404 5404

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
accurate = regressor.score(x_train,y_train)

# %%
print(accurate)
# Out:
# 0.0958026903999245

# %%
print("coefficient: \n", regressor.coef_)
print("intercept: \n",regressor.intercept_)
# Out:
# coefficient:
#  [[0.29666104 0.0394619 ]]
# intercept:
#  [0.00521551]

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
y_pred = regressor.predict(x_train)

# %%
mse = mean_squared_error(y_train,y_pred)

# %%
print("mean squared error is ", mse)
rmse = sqrt(mse)
print(rmse)
# Out:
# mean squared error is  0.9078882925783093
# 0.9528317231171038
